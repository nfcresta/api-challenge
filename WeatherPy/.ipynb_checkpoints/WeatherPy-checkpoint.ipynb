# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 635

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create api_key and units variables
api_key = weather_api_key
units = "imperial"
# Create query url for the api calls
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f'{url}appid={api_key}&units={units}&q='
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=cfae9db35c460a3675b8b4602a4fc056&units=imperial&q='

# %%
# Print beginning lines
print(f'Beginning Data Retrieval')
print(f'-----------------------------')

# Start new empty lists
city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
# Start record counter
record = 1
set_count = 1

# Start a for loop through cities list created above
for i, city in enumerate(cities):
    
    # use if statement to separate data into into sets of up to 50
    if (i % 50 == 0 and i >= 50):
        set_count = set_count + 1
        record = 0
    
    # Use a try statement to start appending calls
    try: 
        response = requests.get(f"{query_url}{city}").json() 
        city_name.append(response["name"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])        
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        city_record = response["name"]
        print(f"Processing Record {record} of Set {set_count} | {city_record}")
        
        # Move on to the next record
        record = record + 1
        
        # set to just over 1 second so we don't exceed the API call limit
        time.sleep(1.01)
        
    # If no record is available, move on to the next call
    except:
        print("City not found. Skipping...")
        
    pass
    
# Print ending lines
print(f'-----------------------------')
print(f'Data Retrieval Complete')      
print(f'-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Christchurch
# Processing Record 2 of Set 1 | Aksha
# Processing Record 3 of Set 1 | Mandalgovi
# Processing Record 4 of Set 1 | Saskylakh
# City not found. Skipping...
# Processing Record 5 of Set 1 | Tuktoyaktuk
# Processing Record 6 of Set 1 | Huanren
# Processing Record 7 of Set 1 | Zhangjiakou
# Processing Record 8 of Set 1 | Coquimbo
# Processing Record 9 of Set 1 | Ostrovnoy
# Processing Record 10 of Set 1 | Qixingtai
# Processing Record 11 of Set 1 | Ushuaia
# Processing Record 12 of Set 1 | Rikitea
# Processing Record 13 of Set 1 | Brigantine
# Processing Record 14 of Set 1 | Torbay
# Processing Record 15 of Set 1 | Punta Arenas
# Processing Record 16 of Set 1 | Huicungo
# Processing Record 17 of Set 1 | Kurumkan
# Processing Record 18 of Set 1 | Severo-Kuril'sk
# Processing Record 19 of Set 1 | Atuona
# Processing Record 20 of Set 1 | Mahibadhoo
# Processing Record 21 of Set 1 | Kloulklubed
# Processing Record 22 of Set 1 | Whitehorse
# Processing Record 23 of Set 1 | Hobart
# Processing Record 24 of Set 1 | Grong
# Processing Record 25 of Set 1 | Okhotsk
# Processing Record 26 of Set 1 | Mataura
# Processing Record 27 of Set 1 | Biak
# Processing Record 28 of Set 1 | Nalgonda
# Processing Record 29 of Set 1 | Arraial do Cabo
# Processing Record 30 of Set 1 | Tondano
# Processing Record 31 of Set 1 | Sept-Îles
# Processing Record 32 of Set 1 | Tema
# Processing Record 33 of Set 1 | Upernavik
# Processing Record 34 of Set 1 | Albany
# Processing Record 35 of Set 1 | Bambous Virieux
# City not found. Skipping...
# Processing Record 36 of Set 1 | Avarua
# Processing Record 37 of Set 1 | Barrow
# Processing Record 38 of Set 1 | Chul'man
# Processing Record 39 of Set 1 | Santa Rosa
# Processing Record 40 of Set 1 | Hilo
# Processing Record 41 of Set 1 | East London
# Processing Record 42 of Set 1 | Leshukonskoye
# Processing Record 43 of Set 1 | Beloha
# Processing Record 44 of Set 1 | Ribeira Grande
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 40 of Set 4 | Vila
# Processing Record 41 of Set 4 | Izhma
# Processing Record 42 of Set 4 | Michigan City
# Processing Record 43 of Set 4 | Pacific Grove
# Processing Record 44 of Set 4 | Bathsheba
# City not found. Skipping...
# Processing Record 0 of Set 5 | Amga
# Processing Record 1 of Set 5 | Shenjiamen
# Processing Record 2 of Set 5 | Okato
# City not found. Skipping...
# Processing Record 3 of Set 5 | Mouila
# Processing Record 4 of Set 5 | Ponta do Sol
# City not found. Skipping...
# Processing Record 5 of Set 5 | Riyadh
# Processing Record 6 of Set 5 | Marawi
# Processing Record 7 of Set 5 | Mackenzie
# Processing Record 8 of Set 5 | Kutum
# Processing Record 9 of Set 5 | Port Moresby
# Processing Record 10 of Set 5 | Kavaratti
# Processing Record 11 of Set 5 | Hambantota
# Processing Record 12 of Set 5 | Coro
# Processing Record 13 of Set 5 | Gondanglegi
# Processing Record 14 of Set 5 | Mahuva
# Processing Record 15 of Set 5 | Nouadhibou
# Processing Record 16 of Set 5 | Pierre
# Processing Record 17 of Set 5 | Chicama
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 5 | Culasi
# Processing Record 19 of Set 5 | Butaritari
# City not found. Skipping...
# Processing Record 20 of Set 5 | Khuzdar
# Processing Record 21 of Set 5 | Grindavik
# Processing Record 22 of Set 5 | Itacoatiara
# Processing Record 23 of Set 5 | Haapiti
# Processing Record 24 of Set 5 | Biłgoraj
# Processing Record 25 of Set 5 | Great Falls
# Processing Record 26 of Set 5 | Manjacaze
# Processing Record 27 of Set 5 | Olafsvik
# Processing Record 28 of Set 5 | Nuquí
# City not found. Skipping...
# Processing Record 29 of Set 5 | Ingham
# Processing Record 30 of Set 5 | Geraldton
# Processing Record 31 of Set 5 | Nago
# Processing Record 32 of Set 5 | Provideniya
# Processing Record 33 of Set 5 | Touros
# Processing Record 34 of Set 5 | Ronda
# Processing Record 35 of Set 5 | Guerrero Negro
# Processing Record 36 of Set 5 | Dingle
# Processing Record 37 of Set 5 | Saint-Alexandre
# Processing Record 38 of Set 5 | Dörtyol
# Processing Record 39 of Set 5 | Saldanha
# Processing Record 40 of Set 5 | Hong Kong
# Processing Record 41 of Set 5 | Ternate
# Processing Record 42 of Set 5 | Lorengau
# Processing Record 43 of Set 5 | Umba
# Processing Record 0 of Set 6 | Mahébourg
# Processing Record 1 of Set 6 | Svelgen
# Processing Record 2 of Set 6 | Ahtopol
# Processing Record 3 of Set 6 | Mahanje
# Processing Record 4 of Set 6 | Menongue
# Processing Record 5 of Set 6 | Qianjiang
# Processing Record 6 of Set 6 | Lárdos
# Processing Record 7 of Set 6 | Rundu
# Processing Record 8 of Set 6 | Longyearbyen
# Processing Record 9 of Set 6 | Alofi
# Processing Record 10 of Set 6 | Yar-Sale
# Processing Record 11 of Set 6 | Qandala
# Processing Record 12 of Set 6 | Naze
# Processing Record 13 of Set 6 | Adrar
# Processing Record 14 of Set 6 | Roebourne
# Processing Record 15 of Set 6 | Bam
# Processing Record 16 of Set 6 | Henties Bay
# Processing Record 17 of Set 6 | Kumul
# Processing Record 18 of Set 6 | Serenje
# Processing Record 19 of Set 6 | Torzhok
# Processing Record 20 of Set 6 | Naustdal
# Processing Record 21 of Set 6 | Forsytheganj
# Processing Record 22 of Set 6 | Comodoro Rivadavia
# Processing Record 23 of Set 6 | Takoradze
# Processing Record 24 of Set 6 | Itarema
# Processing Record 25 of Set 6 | Yulara
# Processing Record 26 of Set 6 | Imeni Poliny Osipenko
# Processing Record 27 of Set 6 | Sozimskiy
# Processing Record 28 of Set 6 | Nachingwea
# Processing Record 29 of Set 6 | Ngorongoro
# Processing Record 30 of Set 6 | Nome
# Processing Record 31 of Set 6 | Mossamedes
# City not found. Skipping...
# Processing Record 32 of Set 6 | Great Yarmouth
# Processing Record 33 of Set 6 | Tazovsky
# Processing Record 34 of Set 6 | Walvis Bay
# Processing Record 35 of Set 6 | Chimbote
# City not found. Skipping...
# Processing Record 36 of Set 6 | Pelagiada
# Processing Record 37 of Set 6 | Saint-Pierre
# Processing Record 38 of Set 6 | Souillac
# Processing Record 39 of Set 6 | Cockburn Town
# Processing Record 40 of Set 6 | Novoagansk
# Processing Record 41 of Set 6 | Pirgos
# Processing Record 42 of Set 6 | Tiksi
# Processing Record 43 of Set 6 | Keighley
# Processing Record 44 of Set 6 | Xiaoweizhai
# City not found. Skipping...
# Processing Record 45 of Set 6 | Teknāf
# Processing Record 46 of Set 6 | Khovd
# City not found. Skipping...
# Processing Record 0 of Set 7 | Chu
# Processing Record 1 of Set 7 | Toora-Khem
# Processing Record 2 of Set 7 | Otradnyy
# Processing Record 3 of Set 7 | Yichang
# Processing Record 4 of Set 7 | Gravdal
# Processing Record 5 of Set 7 | Alyangula
# Processing Record 6 of Set 7 | Tual
# Processing Record 7 of Set 7 | College
# Processing Record 8 of Set 7 | Nehoiu
# Processing Record 9 of Set 7 | Gizo Government Station
# Processing Record 10 of Set 7 | Māngrol
# Processing Record 11 of Set 7 | Zhigansk
# Processing Record 12 of Set 7 | Abu Samrah
# Processing Record 13 of Set 7 | Kaitangata
# Processing Record 14 of Set 7 | Yatou
# Processing Record 15 of Set 7 | Tarauacá
# Processing Record 16 of Set 7 | Port Hardy
# Processing Record 17 of Set 7 | Lebyazh'ye
# Processing Record 18 of Set 7 | Namatanai
# Processing Record 19 of Set 7 | Qian’an
# Processing Record 20 of Set 7 | Oktyabr'skiy
# Processing Record 21 of Set 7 | Charter Township of Clinton
# Processing Record 22 of Set 7 | Kavieng
# Processing Record 23 of Set 7 | Ambilobe
# Processing Record 24 of Set 7 | Dārāb
# Processing Record 25 of Set 7 | Kedgwick
# Processing Record 26 of Set 7 | Kandrian
# City not found. Skipping...
# Processing Record 27 of Set 7 | Songjianghe
# Processing Record 28 of Set 7 | Savalou
# Processing Record 29 of Set 7 | Sarkand
# Processing Record 30 of Set 7 | San Quintín
# City not found. Skipping...
# Processing Record 31 of Set 7 | Libertador General San Martín
# Processing Record 32 of Set 7 | Sabang
# Processing Record 33 of Set 7 | Ugoofaaru
# Processing Record 34 of Set 7 | Sobolevo
# Processing Record 35 of Set 7 | At-Bashi
# Processing Record 36 of Set 7 | Edson
# Processing Record 37 of Set 7 | Isangel
# Processing Record 38 of Set 7 | Potsdam
# Processing Record 39 of Set 7 | Abomey
# Processing Record 19 of Set 9 | Abadiânia
# Processing Record 20 of Set 9 | Paamiut
# Processing Record 21 of Set 9 | San Cristobal
# Processing Record 22 of Set 9 | Yamada
# City not found. Skipping...
# Processing Record 23 of Set 9 | Chara
# Processing Record 24 of Set 9 | Cascais
# Processing Record 25 of Set 9 | Makakilo City
# Processing Record 26 of Set 9 | Port Augusta
# Processing Record 27 of Set 9 | San Policarpo
# City not found. Skipping...
# Processing Record 28 of Set 9 | Ust'-Kulom
# Processing Record 29 of Set 9 | Boyolangu
# Processing Record 30 of Set 9 | Morón
# Processing Record 31 of Set 9 | Pisco
# Processing Record 32 of Set 9 | ‘Āhuimanu
# Processing Record 33 of Set 9 | Juneau
# Processing Record 34 of Set 9 | Tsimmerbude
# City not found. Skipping...
# Processing Record 35 of Set 9 | Sūsangerd
# Processing Record 36 of Set 9 | Palimé
# Processing Record 37 of Set 9 | Cherskiy
# Processing Record 38 of Set 9 | Fort Nelson
# Processing Record 39 of Set 9 | Camaná
# Processing Record 40 of Set 9 | Matagami
# Processing Record 41 of Set 9 | Ipswich
# Processing Record 42 of Set 9 | Barra do Garças
# City not found. Skipping...
# Processing Record 43 of Set 9 | Lázaro Cárdenas
# Processing Record 44 of Set 9 | Grand-Santi
# Processing Record 0 of Set 10 | Mabaruma
# Processing Record 1 of Set 10 | Sol'-Iletsk
# Processing Record 2 of Set 10 | Tateyama
# Processing Record 3 of Set 10 | Cham
# Processing Record 4 of Set 10 | Katsuura
# City not found. Skipping...
# Processing Record 5 of Set 10 | Evanton
# Processing Record 6 of Set 10 | Doha
# Processing Record 7 of Set 10 | Bundaberg
# Processing Record 8 of Set 10 | Pullman
# Processing Record 9 of Set 10 | Luanda
# Processing Record 10 of Set 10 | Bengkulu
# Processing Record 11 of Set 10 | Dalton
# Processing Record 12 of Set 10 | Brumadinho
# Processing Record 13 of Set 10 | Sijunjung
# Processing Record 14 of Set 10 | Camopi
# Processing Record 15 of Set 10 | Ilulissat
# Processing Record 16 of Set 10 | Aberdeen
# Processing Record 17 of Set 10 | Birao
# City not found. Skipping...
# Processing Record 18 of Set 10 | Rosa Zarate
# Processing Record 19 of Set 10 | Mount Isa
# Processing Record 20 of Set 10 | Ust'-Ishim
# Processing Record 21 of Set 10 | Hofn
# Processing Record 22 of Set 10 | Khandagayty
# Processing Record 23 of Set 10 | Kharan
# Processing Record 24 of Set 10 | Kenai
# Processing Record 25 of Set 10 | Salalah
# Processing Record 26 of Set 10 | Koutiala
# Processing Record 27 of Set 10 | Port Blair
# Processing Record 28 of Set 10 | Sittwe
# Processing Record 29 of Set 10 | Oranjemund
# Processing Record 30 of Set 10 | Klaksvík
# Processing Record 31 of Set 10 | Boda
# City not found. Skipping...
# Processing Record 32 of Set 10 | Wala
# City not found. Skipping...
# Processing Record 33 of Set 10 | Rampur Hat
# Processing Record 34 of Set 10 | Estelle
# Processing Record 35 of Set 10 | Inhambane
# Processing Record 36 of Set 10 | Vostok
# City not found. Skipping...
# Processing Record 37 of Set 10 | Pozo Colorado
# Processing Record 38 of Set 10 | Acapulco de Juárez
# Processing Record 39 of Set 10 | Laguna
# Processing Record 40 of Set 10 | Ixtapa
# Processing Record 41 of Set 10 | Ca Mau
# Processing Record 42 of Set 10 | Saint George
# Processing Record 43 of Set 10 | Avilés
# Processing Record 44 of Set 10 | Antofagasta
# Processing Record 0 of Set 11 | St. George's
# Processing Record 1 of Set 11 | Koumac
# City not found. Skipping...
# Processing Record 2 of Set 11 | Arkadelphia
# Processing Record 3 of Set 11 | Snina
# City not found. Skipping...
# Processing Record 4 of Set 11 | Zhaodong
# Processing Record 5 of Set 11 | Zherdevka
# Processing Record 6 of Set 11 | Lakes Entrance
# Processing Record 7 of Set 11 | Itoman
# Processing Record 8 of Set 11 | Sabla
# Processing Record 9 of Set 11 | Copiapó
# Processing Record 10 of Set 11 | Ndélé
# Processing Record 11 of Set 11 | Sineşti
# Processing Record 12 of Set 11 | Te Anau
# Processing Record 13 of Set 11 | Keti Bandar
# Processing Record 14 of Set 11 | Lata
# Processing Record 15 of Set 11 | Yuxia
# Processing Record 16 of Set 11 | Alice Springs
# Processing Record 17 of Set 11 | Malanville
# Processing Record 18 of Set 11 | Minas de Barroterán
# Processing Record 19 of Set 11 | Hualmay
# Processing Record 20 of Set 11 | Islamkot
# Processing Record 21 of Set 11 | Verkhnyaya Inta
# Processing Record 22 of Set 11 | Manokwari
# Processing Record 23 of Set 11 | Mvuma
# Processing Record 24 of Set 11 | Tabou
# Processing Record 25 of Set 11 | Presidencia Roque Sáenz Peña
# Processing Record 26 of Set 11 | Lodja
# Processing Record 27 of Set 11 | Igrim
# Processing Record 28 of Set 11 | Caravelas
# City not found. Skipping...
# Processing Record 29 of Set 11 | Semey
# Processing Record 30 of Set 11 | Omsukchan
# Processing Record 31 of Set 11 | Samarai
# Processing Record 32 of Set 11 | Esim
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 11 | Burns Lake
# Processing Record 34 of Set 11 | Puerto Maldonado
# City not found. Skipping...
# Processing Record 35 of Set 11 | Hamilton
# Processing Record 36 of Set 11 | Tocopilla
# Processing Record 37 of Set 11 | Saint-Joseph
# City not found. Skipping...
# Processing Record 38 of Set 11 | Honningsvåg
# Processing Record 39 of Set 11 | Halifax
# Processing Record 40 of Set 11 | Plettenberg Bay
# Processing Record 41 of Set 11 | Caucayá
# Processing Record 42 of Set 11 | Ottawa
# Processing Record 0 of Set 12 | Tura
# Processing Record 1 of Set 12 | Tangjiazhuang
# Processing Record 2 of Set 12 | Doka
# Processing Record 3 of Set 12 | Santa Fe
# Processing Record 4 of Set 12 | Lakhdenpokh'ya
# Processing Record 5 of Set 12 | São Filipe
# Processing Record 6 of Set 12 | Safranbolu
# Processing Record 7 of Set 12 | Pangai
# Processing Record 8 of Set 12 | Brufut
# Processing Record 9 of Set 12 | Águilas
# Processing Record 10 of Set 12 | Naya Bāzār
# Processing Record 11 of Set 12 | Ust'-Koksa
# Processing Record 12 of Set 12 | Sagvåg
# Processing Record 13 of Set 12 | Alice Town
# Processing Record 14 of Set 12 | Korla
# Processing Record 15 of Set 12 | Bystryy Istok
# Processing Record 16 of Set 12 | Tinskoy
# Processing Record 17 of Set 12 | Annur
# Processing Record 18 of Set 12 | La Romana
# Processing Record 19 of Set 12 | Ust'-Tarka
# Processing Record 20 of Set 12 | Spirovo
# Processing Record 21 of Set 12 | Umeå
# Processing Record 22 of Set 12 | Santa Cruz de la Sierra
# Processing Record 23 of Set 12 | Palana
# Processing Record 24 of Set 12 | Dzhebariki-Khaya
# Processing Record 25 of Set 12 | Mayumba
# Processing Record 26 of Set 12 | Shāhpura
# Processing Record 27 of Set 12 | Eyl
# Processing Record 28 of Set 12 | Tigil'
# Processing Record 29 of Set 12 | Tonstad
# Processing Record 30 of Set 12 | Vardø
# Processing Record 31 of Set 12 | Ahipara
# Processing Record 32 of Set 12 | Lavrentiya
# Processing Record 33 of Set 12 | Lianran
# Processing Record 34 of Set 12 | Sakakah
# Processing Record 35 of Set 12 | Batagay-Alyta
# Processing Record 36 of Set 12 | Siparia
# Processing Record 37 of Set 12 | Kiama
# Processing Record 38 of Set 12 | Banda Aceh
# Processing Record 39 of Set 12 | Tiverton
# Processing Record 40 of Set 12 | Natchez
# Processing Record 41 of Set 12 | São João da Barra
# Processing Record 42 of Set 12 | Tezu
# Processing Record 43 of Set 12 | Kedrovoye
# Processing Record 44 of Set 12 | Auki
# Processing Record 45 of Set 12 | Āsosa
# Processing Record 46 of Set 12 | Brae
# Processing Record 47 of Set 12 | Palmer
# City not found. Skipping...
# Processing Record 48 of Set 12 | Ciudad Bolivar
# Processing Record 0 of Set 13 | Sāyla
# Processing Record 1 of Set 13 | Vanimo
# Processing Record 2 of Set 13 | Ola
# Processing Record 3 of Set 13 | Bariloche
# Processing Record 4 of Set 13 | Río Gallegos
# Processing Record 5 of Set 13 | Verkhnyaya Maksakovka
# Processing Record 6 of Set 13 | Sirte
# Processing Record 7 of Set 13 | Olovyannaya
# Processing Record 8 of Set 13 | Aksu
# Processing Record 9 of Set 13 | Pedernales
# Processing Record 10 of Set 13 | Dolores
# Processing Record 11 of Set 13 | Pangnirtung
# Processing Record 12 of Set 13 | Sainte-Anne-des-Monts
# Processing Record 13 of Set 13 | Sørland
# Processing Record 14 of Set 13 | San Vicente
# Processing Record 15 of Set 13 | Lüderitz
# Processing Record 16 of Set 13 | União
# Processing Record 17 of Set 13 | Viseu
# City not found. Skipping...
# Processing Record 18 of Set 13 | Simões
# Processing Record 19 of Set 13 | Muzhi
# Processing Record 20 of Set 13 | Augsburg
# Processing Record 21 of Set 13 | Rebrikha
# Processing Record 22 of Set 13 | Saint Anthony
# Processing Record 23 of Set 13 | Kostomuksha
# Processing Record 24 of Set 13 | Trenggalek
# Processing Record 25 of Set 13 | Jiujiang
# Processing Record 26 of Set 13 | Hutchinson
# Processing Record 27 of Set 13 | Hastings
# City not found. Skipping...
# Processing Record 28 of Set 13 | Broken Hill
# Processing Record 29 of Set 13 | Eureka
# Processing Record 30 of Set 13 | Carberry
# Processing Record 31 of Set 13 | Faya
# Processing Record 32 of Set 13 | Marabu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df = pd.DataFrame({
    "City": city_name,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
})

cities_df.to_csv("WeatherPy.csv",index=False)

cities_df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Christchurch -43.53  172.63     52.00        76          52        8.05
# 1         Aksha  50.28  113.29     -2.69        86           4        4.45
# 2    Mandalgovi  45.76  106.27     -2.09        87         100        5.26
# 3     Saskylakh  71.92  114.08    -27.27        84         100        5.97
# 4   Tuktoyaktuk  69.45 -133.04    -22.00        74          20        8.05
#
#   Country        Date
# 0      NZ  1607708120
# 1      RU  1607708186
# 2      MN  1607708187
# 3      RU  1607708188
# 4      CA  1607708189

# %%
cities_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  582.000000  582.000000  582.000000  582.000000  582.000000  582.000000
# mean    20.969863   19.957440   52.250223   74.817869   52.515464    8.372990
# std     33.721258   89.806669   30.602963   18.900532   36.967990    5.957783
# min    -54.800000 -175.200000  -42.480000   10.000000    0.000000    0.450000
# 25%     -7.520000  -58.785000   32.000000   67.000000   20.000000    4.245000
# 50%     24.810000   24.665000   62.600000   79.000000   54.000000    6.930000
# 75%     50.827500   96.732500   77.220000   88.000000   90.000000   11.410000
# max     78.220000  179.320000  102.000000  100.000000  100.000000   34.450000
#
#                Date
# count  5.820000e+02
# mean   1.607708e+09
# std    2.736861e+02
# min    1.607708e+09
# 25%    1.607708e+09
# 50%    1.607708e+09
# 75%    1.607709e+09
# max    1.607709e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
max_hum = cities_df["Humidity"].max()
print(f"The maximum humidity is {max_hum}%.")
print(f"There are NO cities in the DF that exceed 100% humidity.")
# Out:
# The maximum humidity is 100%.
# There are NO cities in the DF that exceed 100% humidity.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create variables
latitude = cities_df["Lat"]
maximum_temp = cities_df["Max Temp"]

# Create scatter plot
plt.scatter(latitude, maximum_temp, marker="o", edgecolor="black", alpha=0.7)
plt.title("City Latitude vs. Max Temperature (12/10/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("../output_data/lat_temp.png")
plt.show()

# %% [markdown]
# This plot shows that the closer a city is to the equator, the higher the max temperature will be.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create variables and scatter plot
latitude = cities_df["Lat"]
humidity = cities_df["Humidity"]

# Create scatter plot
plt.scatter(latitude, humidity, marker="o", edgecolor="black", alpha=0.7)
plt.title("City Latitude vs. Humidity (12/10/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("../output_data/lat_humidity.png")
plt.show()

# %% [markdown]
# This plot shows that there is not much of a correlation between latitude and humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create variables
latitude = cities_df["Lat"]
cloudiness = cities_df["Cloudiness"]

# Create Scatter Plot
plt.scatter(latitude, cloudiness, marker="o", edgecolor="black", alpha=0.7)
plt.title("City Latitude vs. Cloudiness (12/10/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("../output_data/lat_cloudiness.png")
plt.show()

# %% [markdown]
# There seems to be no correlation between latitude and cloudiness as well.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create variables
latitude = cities_df["Lat"]
wind = cities_df["Wind Speed"]

# Create Scatter Plot
plt.scatter(latitude, wind, marker="o", edgecolor="black", alpha=0.7)
plt.title("City Latitude vs. Wind Speed (12/10/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("../output_data/lat_windspeed.png")
plt.show()

# %% [markdown]
# Though there isn't much of a correlation, it seems that cities which are further away from the equator have the potential for higher wind speeds.

# %% [markdown]
# ## Linear Regression

# %%
# Import linregress
from scipy.stats import linregress

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create variables
north_cities = cities_df[cities_df["Lat"] >= 0] 
latitude = north_cities["Lat"]
maximum_temp = north_cities["Max Temp"]

# Calculate linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, maximum_temp)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot w/ linear regression analysis
plt.scatter(latitude, maximum_temp, marker="o")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(0,20),fontsize=15,color="red")
plt.title("Northern Hemisphere City Latitude vs. Max Temperature (12/10/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The r-value is: {rvalue}")
plt.savefig("../output_data/north_lat_temp_regression.png")
plt.show()
# Out:
# The r-value is: -0.851236470261996

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create variables
south_cities = cities_df[cities_df["Lat"] < 0] 
latitude = south_cities["Lat"]
maximum_temp = south_cities["Max Temp"]
# date = cities_df["date"].unique()

# Calculate linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, maximum_temp)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot w/ linear regression analysis
plt.scatter(latitude, maximum_temp, marker="o")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-55,90),fontsize=15,color="red")
plt.title("Southern Hemisphere City Latitude vs. Max Temperature (12/10/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The r-value is: {rvalue}")
plt.savefig("../output_data/south_lat_temp_regression.png")
plt.show()
# Out:
# The r-value is: 0.5999081937102035

# %% [markdown]
# According to these two regression models for latitude vs. maximum temperature, there is a positive correlation as the the latitude moves closer to 0 and a negative correlation as the latitude moves futher away from 0. This means that as the maximum temperatures for both models are highest at the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create variables
latitude = north_cities["Lat"]
humidity = north_cities["Humidity"]

# Calculate linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter and plot linear regression analysis
plt.scatter(latitude, humidity, marker="o")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.title("Northern Hemisphere City Latitude vs. Humidity (12/10/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-value is: {rvalue}")
plt.savefig("../output_data/north_lat_humidity_regression.png")
plt.show()
# Out:
# The r-value is: 0.41155609706319335

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create variables 
latitude = south_cities["Lat"]
humidity = south_cities["Humidity"]

# Calculate linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot and include linear regression model
plt.scatter(latitude, humidity, marker="o")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-55,40),fontsize=15,color="red")
plt.title("Southern Hemisphere City Latitude vs. Humidity (12/10/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-value is: {rvalue}")
plt.savefig("../output_data/south_lat_humidity_regression.png")
plt.show()
# Out:
# The r-value is: 0.21616464682312297

# %% [markdown]
# When lookin at the data, the regression models are very similar. There isn't much analysis to be done here as it seems there is a positive trend for humidity as moving up from the southern hemisphere to the equator, and also a positive trend when moving up from the equator to the northern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create variables
latitude = north_cities["Lat"]
cloudiness = north_cities["Cloudiness"]

# Calculate linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot and include linear regression model
plt.scatter(latitude, cloudiness, marker="o")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(40,25),fontsize=15,color="red")
plt.title("Northern Hemisphere City Latitude vs. Cloudiness (12/10/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-value is: {rvalue}")
plt.savefig("../output_data/north_lat_cloudiness_regression.png")
plt.show()
# Out:
# The r-value is: 0.28418858134753555

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create variables
latitude = south_cities["Lat"]
cloudiness = south_cities["Cloudiness"]

# Calculate linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot and include linear regression model
plt.scatter(latitude, cloudiness, marker="o")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-55,40),fontsize=15,color="red")
plt.title("Southern Hemisphere City Latitude vs. Cloudiness (12/10/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-value is: {rvalue}")
plt.savefig("../output_data/south_lat_cloudiness_regression.png")
plt.show()
# Out:
# The r-value is: 0.09081069866209873

# %% [markdown]
# Similar to humidity, there is a positive correlation moving from the southern hemisphere to the equator and a positive correlation moving up from the equator to the nothern hemisphere in terms of cloudiness. The correlation more than twice as strong, however, when moving from the equator through the northern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create variables
latitude = north_cities["Lat"]
wind_speed = north_cities["Wind Speed"]

# Calculate linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind_speed)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot and include linear regression model
plt.scatter(latitude, wind_speed, marker="o")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(40,25),fontsize=15,color="red")
plt.title("Northern Hemisphere City Latitude vs. Wind Speed (12/10/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
print(f"The r-value is: {rvalue}")
plt.savefig("../output_data/north_lat_windspeed_regression.png")
plt.show()
# Out:
# The r-value is: 0.09418124939123837

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create variables 
latitude = south_cities["Lat"]
wind_speed = south_cities["Wind Speed"]

# Calculate linear regression model
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind_speed)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot and include linear regression model
plt.scatter(latitude, wind_speed, marker="o")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-35,25),fontsize=15,color="red")
plt.title("Southern Hemisphere City Latitude vs. Wind Speed (12/10/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
print(f"The r-value is: {rvalue}")
plt.savefig("../output_data/south_lat_windspeed_regression.png")
plt.show()
# Out:
# The r-value is: -0.38005072571279885

# %% [markdown]
# As described earler in the combined latitude vs. windspeed scatter plot, the regression shows that the further a city is away from the equator, the higher the potential there is for increased wind speeds.
